# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import re

from tensorflow.keras.layers import Dense, LSTM, Input, Dropout, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('drive/MyDrive/train_data_true1.txt', 'r', encoding='utf-8') as f:
    texts_true = f.readlines()
    texts_true[0] = texts_true[0].replace('\ufeff', '') #убираем первый невидимый символ

with open('drive/MyDrive/train_data_false1.txt', 'r', encoding='utf-8') as f:
    texts_false = f.readlines()
    texts_false[0] = texts_false[0].replace('\ufeff', '') #убираем первый невидимый символ

# %%
len(texts_true)
# Out:
# 500

# %%
len(texts_false)
# Out:
# 500

# %%
texts = texts_true + texts_false
count_true = len(texts_true)
count_false = len(texts_false)
total_lines = count_true + count_false
print(count_true, count_false, total_lines)


maxWordsCount = 1000
tokenizer = Tokenizer(num_words=maxWordsCount, filters='!–"—#$%&amp;()*+,-./:;<=>?@[\\]^_`{|}~\t\n\r«»', lower=True, split=' ', char_level=False)
tokenizer.fit_on_texts(texts)

dist = list(tokenizer.word_counts.items())
print(dist[:10])
print(texts[0][:100])


max_text_len = 10
data = tokenizer.texts_to_sequences(texts)
data_pad = pad_sequences(data, maxlen=max_text_len)
print(data_pad)

print( list(tokenizer.word_index.items()) )


X = data_pad
Y = np.array([[1, 0]]*count_true + [[0, 1]]*count_false)
print(X.shape, Y.shape)

indeces = np.random.choice(X.shape[0], size=X.shape[0], replace=False)
X = X[indeces]
Y = Y[indeces]


model = Sequential()
model.add(Embedding(maxWordsCount, 128, input_length = max_text_len))
model.add(LSTM(128, return_sequences=True))
model.add(LSTM(64))
model.add(Dense(2, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=Adam(0.0001))

history = model.fit(X, Y, batch_size=32, epochs=50)

reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))

def sequence_to_text(list_of_indices):
    words = [reverse_word_map.get(letter) for letter in list_of_indices]
    return(words)

t = "Каждый новый день приносит радость, вдохновение и возможности для роста, а ваше сердце наполняется светом и благодарностью".lower()
# t = "Я никогда не сяду за руль, это же смертельно опасно! ".lower()
data = tokenizer.texts_to_sequences([t])
data_pad = pad_sequences(data, maxlen=max_text_len)
print( sequence_to_text(data[0]) )

res = model.predict(data_pad)
print(res, np.argmax(res), sep='\n')
# Out:
# 500 500 1000
# [('думайте', 1), ('позитивно', 1), ('и', 174), ('верьте', 2), ('в', 131), ('свою', 12), ('способность', 1), ('достигать', 2), ('отличных', 1), ('результатов', 2)]
# Думайте позитивно и верьте в свою способность достигать отличных результатов.
#
# [[707 708   2 ... 402 710 403]
#  [  0   1 711 ... 713   3 287]
#  [714   3 287 ...   1 717 718]
#  ...
#  [  0   0   0 ...  59 702 199]
#  [  0   0   0 ... 344   7 286]
#  [  0   0   0 ...  34  11 204]]
# [('вы', 1), ('и', 2), ('в', 3), ('не', 4), ('все', 5), ('ваша', 6), ('что', 7), ('день', 8), ('ваши', 9), ('это', 10), ('на', 11), ('каждый', 12), ('нет', 13), ('для', 14), ('к', 15), ('мир', 16), ('каждая', 17), ('вокруг', 18), ('жизни', 19), ('находите', 20), ('жизнь', 21), ('себя', 22), ('ощущение', 23), ('с', 24), ('помните', 25), ('даже', 26), ('вас', 27), ('обладаете', 28), ('приносит', 29), ('позитивные', 30), ('силы', 31), ('будто', 32), ('мысли', 33), ('как', 34), ('новые', 35), ('вам', 36), ('заслуживаете', 37), ('достойны', 38), ('чувствую', 39), ('каждое', 40), ('радость', 41), ('слишком', 42), ('создаете', 43), ('будущее', 44), ('ваш', 45), ('силой', 46), ('кажется', 47), ('мечты', 48), ('о', 49), ('постоянно', 50), ('каждом', 51), ('до', 52), ('вера', 53), ('ваше', 54), ('ничего', 55), ('утро', 56), ('то', 57), ('возможности', 58), ('чем', 59), ('больше', 60), ('всё', 61), ('никакого', 62), ('надежда', 63), ('за', 64), ('внутренняя', 65), ('создают', 66), ('видите', 67), ('свою', 68), ('так', 69), ('уверенность', 70), ('возможность', 71), ('лучше', 72), ('только', 73), ('становится', 74), ('сил', 75), ('чувство', 76), ('вашей', 77), ('лучшему', 78), ('делает', 79), ('вашу', 80), ('вселенная', 81), ('время', 82), ('создаёте', 83), ('стало', 84), ('роста', 85), ('всегда', 86), ('чудеса', 87), ('словно', 88), ('которые', 89), ('хорошее', 90), ('удачу', 91), ('реальность', 92), ('способны', 93), ('любви', 94), ('позитивное', 95), ('ни', 96), ('своей', 97), ('люди', 98), ('настроение', 99), ('сердце', 100), ('от', 101), ('идет', 102), ('никто', 103), ('смысла', 104), ('полностью', 105), ('постоянное', 106), ('без', 107), ('новый', 108), ('изменить', 109), ('оптимизм', 110), ('проблема', 111), ('энергия', 112), ('радости', 113), ('людей', 114), ('свет', 115), ('других', 116), ('события', 117), ('притягиваете', 118), ('ситуации', 119), ('напоминает', 120), ('никому', 121), ('одиночество', 122), ('разочарование', 123), ('быстро', 124), ('полной', 125), ('раздражение', 126), ('проблемы', 127), ('себе', 128), ('привлекает', 129), ('новых', 130), ('сила', 131), ('каждым', 132), ('решимость', 133), ('лучшее', 134), ('трудность', 135), ('счастья', 136), ('привлекаете', 137), ('настрой', 138), ('самых', 139), ('душа', 140), ('видят', 141), ('слова', 142), ('вдохновение', 143), ('настоящей', 144), ('а', 145), ('из', 146), ('раздражает', 147), ('веры', 148), ('вызывает', 149), ('энергии', 150), ('простые', 151), ('окончательно', 152), ('желания', 153), ('казались', 154), ('чтобы', 155), ('сильнее', 156), ('быть', 157), ('успеха', 158), ('помогает', 159), ('будет', 160), ('смелостью', 161), ('мышление', 162), ('изменения', 163), ('гармония', 164), ('вибрации', 165), ('привлекают', 166), ('страсть', 167), ('мудростью', 168), ('решения', 169), ('таланты', 170), ('позитивный', 171), ('действия', 172), ('красоту', 173), ('другим', 174), ('где', 175), ('глаза', 176), ('руки', 177), ('но', 178), ('дела', 179), ('валится', 180), ('весь', 181), ('планы', 182), ('неудачи', 183), ('постоянные', 184), ('сложно', 185), ('никаких', 186), ('тяжело', 187), ('иногда', 188), ('оставляя', 189), ('шанс', 190), ('любые', 191), ('трудности', 192), ('новым', 193), ('целей', 194), ('вдохновляет', 195), ('задачи', 196), ('всех', 197), ('ведет', 198), ('бы', 199), ('любовь', 200), ('устойчивость', 201), ('прекрасные', 202), ('путь', 203), ('уже', 204), ('несут', 205), ('вашего', 206), ('по', 207), ('пространство', 208), ('поддержки', 209), ('меняется', 210), ('несмотря', 211), ('понимает', 212), ('выхода', 213), ('терпения', 214), ('этом', 215), ('постоянная', 216), ('медленно', 217), ('любых', 218), ('преодолевать', 219), ('успех', 220), ('улыбка', 221), ('всего', 222), ('самого', 223), ('причины', 224), ('творит', 225), ('открывает', 226), ('подарок', 227), ('минута', 228), ('создавать', 229), ('днем', 230), ('гармонию', 231), ('энергией', 232), ('особенный', 233), ('благословения', 234), ('прекрасную', 235), ('улучшений', 236), ('учит', 237), ('дает', ...
# (1000, 10) (1000, 2)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_7 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_14 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_15 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5684 - loss: 0.6896
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5448 - loss: 0.6740
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5922 - loss: 0.6335
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7619 - loss: 0.5594
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8940 - loss: 0.4069
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9414 - loss: 0.2153
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9707 - loss: 0.1034
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9727 - loss: 0.0859
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9856 - loss: 0.0392
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9906 - loss: 0.0274
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9927 - loss: 0.0260
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9884 - loss: 0.0302
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9899 - loss: 0.0266
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9967 - loss: 0.0121
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9953 - loss: 0.0161
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9981 - loss: 0.0101
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9931 - loss: 0.0196
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9972 - loss: 0.0090
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9992 - loss: 0.0076
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9991 - loss: 0.0065
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9988 - loss: 0.0086
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0087
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9946 - loss: 0.0100
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9984 - loss: 0.0038
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9946 - loss: 0.0096
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9941 - loss: 0.0078
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9997 - loss: 0.0020
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9989 - loss: 0.0036
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9975 - loss: 0.0034
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9983 - loss: 0.0042
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9993 - loss: 0.0022
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9986 - loss: 0.0045
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9998 - loss: 0.0020
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9979 - loss: 0.0042
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9992 - loss: 0.0024
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9985 - loss: 0.0041
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9993 - loss: 0.0034
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9999 - loss: 0.0012
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9994 - loss: 0.0017
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9990 - loss: 0.0043
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9993 - loss: 0.0017
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9991 - loss: 0.0040
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9991 - loss: 0.0040
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0018
# ['каждый', 'новый', 'день', 'приносит', 'радость', 'вдохновение', 'и', 'возможности', 'для', 'роста', 'а', 'ваше', 'сердце', 'светом', 'и']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# [[9.996728e-01 3.272659e-04]]
# 0

# %%
texts = texts_true + texts_false
count_true = len(texts_true)
count_false = len(texts_false)
total_lines = count_true + count_false
print(count_true, count_false, total_lines)


maxWordsCount = 1000
tokenizer = Tokenizer(num_words=maxWordsCount, filters='!–"—#$%&amp;()*+,-./:;<=>?@[\\]^_`{|}~\t\n\r«»', lower=True, split=' ', char_level=False)
tokenizer.fit_on_texts(texts)

dist = list(tokenizer.word_counts.items())
print(dist[:10])
print(texts[0][:100])


max_text_len = 10
data = tokenizer.texts_to_sequences(texts)
data_pad = pad_sequences(data, maxlen=max_text_len)
print(data_pad)

print( list(tokenizer.word_index.items()) )


X = data_pad
Y = np.array([[1, 0]]*count_true + [[0, 1]]*count_false)
print(X.shape, Y.shape)

indeces = np.random.choice(X.shape[0], size=X.shape[0], replace=False)
X = X[indeces]
Y = Y[indeces]


model = Sequential()
model.add(Embedding(maxWordsCount, 128, input_length = max_text_len))
model.add(LSTM(128, return_sequences=True))
model.add(LSTM(64))
model.add(Dense(2, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=Adam(0.0001))

history = model.fit(X, Y, batch_size=32, epochs=50)

reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))

def sequence_to_text(list_of_indices):
    words = [reverse_word_map.get(letter) for letter in list_of_indices]
    return(words)


t = "Я никогда не сяду за руль, это же смертельно опасно! ".lower()
data = tokenizer.texts_to_sequences([t])
data_pad = pad_sequences(data, maxlen=max_text_len)
print( sequence_to_text(data[0]) )

res = model.predict(data_pad)
print(res, np.argmax(res), sep='\n')
# Out:
# 500 500 1000
# [('думайте', 1), ('позитивно', 1), ('и', 174), ('верьте', 2), ('в', 131), ('свою', 12), ('способность', 1), ('достигать', 2), ('отличных', 1), ('результатов', 2)]
# Думайте позитивно и верьте в свою способность достигать отличных результатов.
#
# [[707 708   2 ... 402 710 403]
#  [  0   1 711 ... 713   3 287]
#  [714   3 287 ...   1 717 718]
#  ...
#  [  0   0   0 ...  59 702 199]
#  [  0   0   0 ... 344   7 286]
#  [  0   0   0 ...  34  11 204]]
# [('вы', 1), ('и', 2), ('в', 3), ('не', 4), ('все', 5), ('ваша', 6), ('что', 7), ('день', 8), ('ваши', 9), ('это', 10), ('на', 11), ('каждый', 12), ('нет', 13), ('для', 14), ('к', 15), ('мир', 16), ('каждая', 17), ('вокруг', 18), ('жизни', 19), ('находите', 20), ('жизнь', 21), ('себя', 22), ('ощущение', 23), ('с', 24), ('помните', 25), ('даже', 26), ('вас', 27), ('обладаете', 28), ('приносит', 29), ('позитивные', 30), ('силы', 31), ('будто', 32), ('мысли', 33), ('как', 34), ('новые', 35), ('вам', 36), ('заслуживаете', 37), ('достойны', 38), ('чувствую', 39), ('каждое', 40), ('радость', 41), ('слишком', 42), ('создаете', 43), ('будущее', 44), ('ваш', 45), ('силой', 46), ('кажется', 47), ('мечты', 48), ('о', 49), ('постоянно', 50), ('каждом', 51), ('до', 52), ('вера', 53), ('ваше', 54), ('ничего', 55), ('утро', 56), ('то', 57), ('возможности', 58), ('чем', 59), ('больше', 60), ('всё', 61), ('никакого', 62), ('надежда', 63), ('за', 64), ('внутренняя', 65), ('создают', 66), ('видите', 67), ('свою', 68), ('так', 69), ('уверенность', 70), ('возможность', 71), ('лучше', 72), ('только', 73), ('становится', 74), ('сил', 75), ('чувство', 76), ('вашей', 77), ('лучшему', 78), ('делает', 79), ('вашу', 80), ('вселенная', 81), ('время', 82), ('создаёте', 83), ('стало', 84), ('роста', 85), ('всегда', 86), ('чудеса', 87), ('словно', 88), ('которые', 89), ('хорошее', 90), ('удачу', 91), ('реальность', 92), ('способны', 93), ('любви', 94), ('позитивное', 95), ('ни', 96), ('своей', 97), ('люди', 98), ('настроение', 99), ('сердце', 100), ('от', 101), ('идет', 102), ('никто', 103), ('смысла', 104), ('полностью', 105), ('постоянное', 106), ('без', 107), ('новый', 108), ('изменить', 109), ('оптимизм', 110), ('проблема', 111), ('энергия', 112), ('радости', 113), ('людей', 114), ('свет', 115), ('других', 116), ('события', 117), ('притягиваете', 118), ('ситуации', 119), ('напоминает', 120), ('никому', 121), ('одиночество', 122), ('разочарование', 123), ('быстро', 124), ('полной', 125), ('раздражение', 126), ('проблемы', 127), ('себе', 128), ('привлекает', 129), ('новых', 130), ('сила', 131), ('каждым', 132), ('решимость', 133), ('лучшее', 134), ('трудность', 135), ('счастья', 136), ('привлекаете', 137), ('настрой', 138), ('самых', 139), ('душа', 140), ('видят', 141), ('слова', 142), ('вдохновение', 143), ('настоящей', 144), ('а', 145), ('из', 146), ('раздражает', 147), ('веры', 148), ('вызывает', 149), ('энергии', 150), ('простые', 151), ('окончательно', 152), ('желания', 153), ('казались', 154), ('чтобы', 155), ('сильнее', 156), ('быть', 157), ('успеха', 158), ('помогает', 159), ('будет', 160), ('смелостью', 161), ('мышление', 162), ('изменения', 163), ('гармония', 164), ('вибрации', 165), ('привлекают', 166), ('страсть', 167), ('мудростью', 168), ('решения', 169), ('таланты', 170), ('позитивный', 171), ('действия', 172), ('красоту', 173), ('другим', 174), ('где', 175), ('глаза', 176), ('руки', 177), ('но', 178), ('дела', 179), ('валится', 180), ('весь', 181), ('планы', 182), ('неудачи', 183), ('постоянные', 184), ('сложно', 185), ('никаких', 186), ('тяжело', 187), ('иногда', 188), ('оставляя', 189), ('шанс', 190), ('любые', 191), ('трудности', 192), ('новым', 193), ('целей', 194), ('вдохновляет', 195), ('задачи', 196), ('всех', 197), ('ведет', 198), ('бы', 199), ('любовь', 200), ('устойчивость', 201), ('прекрасные', 202), ('путь', 203), ('уже', 204), ('несут', 205), ('вашего', 206), ('по', 207), ('пространство', 208), ('поддержки', 209), ('меняется', 210), ('несмотря', 211), ('понимает', 212), ('выхода', 213), ('терпения', 214), ('этом', 215), ('постоянная', 216), ('медленно', 217), ('любых', 218), ('преодолевать', 219), ('успех', 220), ('улыбка', 221), ('всего', 222), ('самого', 223), ('причины', 224), ('творит', 225), ('открывает', 226), ('подарок', 227), ('минута', 228), ('создавать', 229), ('днем', 230), ('гармонию', 231), ('энергией', 232), ('особенный', 233), ('благословения', 234), ('прекрасную', 235), ('улучшений', 236), ('учит', 237), ('дает', ...
# (1000, 10) (1000, 2)
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_8 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_16 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_17 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5343 - loss: 0.6899
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5511 - loss: 0.6741
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5695 - loss: 0.6507
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6806 - loss: 0.5701
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8722 - loss: 0.4172
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9465 - loss: 0.2184
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9737 - loss: 0.1050
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9733 - loss: 0.0651
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9909 - loss: 0.0343
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9928 - loss: 0.0300
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9829 - loss: 0.0343
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9885 - loss: 0.0237
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9953 - loss: 0.0153
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9909 - loss: 0.0292
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9973 - loss: 0.0103
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9976 - loss: 0.0134
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9977 - loss: 0.0093
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9981 - loss: 0.0100
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9953 - loss: 0.0101
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9979 - loss: 0.0084
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9968 - loss: 0.0078
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9999 - loss: 0.0051
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9960 - loss: 0.0106
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9970 - loss: 0.0073
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9994 - loss: 0.0028
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9996 - loss: 0.0040
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9967 - loss: 0.0057
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9995 - loss: 0.0021
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9999 - loss: 0.0030
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9992 - loss: 0.0030
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9998 - loss: 0.0019
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9960 - loss: 0.0077
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9999 - loss: 0.0011
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9891 - loss: 0.0416
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9975 - loss: 0.0069
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9994 - loss: 0.0020
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 8.7391e-04
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 8.5470e-04
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9999 - loss: 0.0011
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 8.7825e-04
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9983 - loss: 0.0021
# ['я', 'никогда', 'не', 'за', 'это', 'же']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# [[1.459274e-04 9.998541e-01]]
# 1
